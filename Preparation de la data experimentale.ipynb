# %%
import pandas as pd
from herows import *

# %%
data = pd.read_excel("cleanData.xlsx")
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#                                  Alloy         A     delta           TM  \
# 0                         Al0.2MoTaTiV  1.990476  0.040740  2489.114286
# 1                         Al0.6MoTaTiV  1.973913  0.047752  2353.834783
# 2                         Al1.5MoNbTiV  1.945455  0.055290  2025.400000
# 3     Hf1.375Nb0.25Ta0.25Ti1.75Zr1.375  2.120000  0.043743  2249.075000
# 4                      Mo0.1NbTiV0.3Zr  2.079412  0.046332  2276.767647
# ...                                ...       ...       ...          ...
# 2324                     FeNiCrCoAl2.5  1.339231  0.058390  1510.873077
# 2325                     FeCoNiCrCuAl3  1.333750  0.060208  1455.647500
# 2326               CrMo0.5NbTa0.5TiZr   1.583000  0.094252  2418.400000
# 2327                       CrHfNbTiZr   1.278000  0.512586  2301.000000
# 2328                              AuRu  1.390000  0.035971  1972.165000
#
#       DELTA_TM  Electronegativity  Delta_Electro-        SID       VEC  \
# ...

# %%
list(data["Alloy"])
# Out:
# ['Al0.2MoTaTiV',
#  'Al0.6MoTaTiV',
#  'Al1.5MoNbTiV',
#  'Hf1.375Nb0.25Ta0.25Ti1.75Zr1.375',
#  'Mo0.1NbTiV0.3Zr',
#  'Mo0.3NbTiV0.3Zr',
#  'Mo0.5NbTiV0.3Zr',
#  'Mo0.7NbTiV0.3Zr',
#  'Mo1.3NbTiV0.3Zr',
#  'Mo1.5NbTiV0.3Zr',
#  'MoNbTaTi0.25W',
#  'MoNbTaTi0.5W',
#  'MoNbTaTi0.75W',
#  'MoNbTiV0.3Zr',
#  'CoCrCu1FeNiTi0.5',
#  'VCrFeTa0.1W0.1',
#  'VCrFeTa0.2W0.2',
#  'VCrFeTa0.4W0.4',
#  'Al65Cu5Fe5Mg5Si15Zn5',
#  'Al65Cu5Mg5Ni5Si15Zn5',
#  'Al70Cr5Cu5Mg5Si10Zn5',
#  'Al70Cu5Mg5Mn5Si10Zn5',
#  'Al70Cu5Mg5Si10Zn5Zr5',
#  'Nb42Mo20Ti13Cr12V12Ta1',
#  'NbTaTi30Zr',
#  'NbTaTi35Zr',
#  'NbTaTi40Zr',
#  'NbTaTi45Zr',
#  'Ta0.6ZrHfTi',
#  'Ta0.5ZrHfTi',
#  'Ta0.4ZrHfTi',
#  'Ti40Zr25Nb25Ta10',
#  'Ti45Zr25Nb25Ta5',
#  'Ti35Zr25Nb25Ta15',
#  'Ti30Zr25Nb25Ta20',
#  'Ti25Zr25Nb25Ta25',
#  'AlCoCrFeNiV0.2',
#  'AlCoCrFeNiV0.5',
#  'AlCoCrFeNiV0.8',
#  'AlCoCrFeNiV1.0',
#  'Al1.8CoCrFeNiTi0.2',
#  'Al1.5CoCrFeNiTi0.5',
#  'Al1.2CoCrFeNiTi0.8',
#  'Al0.8CoCrFeNiTi1.2',
#  'Al0.5HfNbTiZr',
# ...

# %%
df = pd.read_excel("hhh2.xlsx")

# %%
import pandas as pd
import re

# List of all elements in the periodic table (you might need to add more elements)
periodic_table_elements = ['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Ni', 'Co', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se', 'Br', 'Kr', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Te', 'I', 'Xe', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn', 'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr']

# Function to extract elements from the index using regex
def extract_elements(index_string):
    elements = re.findall(r'[A-Z][a-z]*', index_string)  # Using regex to find elements
    return [element for element in elements if element in periodic_table_elements]

# Apply the extract_elements function to each row in the "index" column
df['extracted_elements'] = df['index'].apply(extract_elements)

# Extract all unique elements from the "extracted_elements" column
all_unique_elements_calc = list(set(element for sublist in df['extracted_elements'] for element in sublist))

print(all_unique_elements_calc)
len(all_unique_elements_calc)
# Out:
# ['Re', 'In', 'Mn', 'Ti', 'As', 'V', 'Ta', 'Ga', 'Cu', 'Ru', 'Zn', 'Sn', 'Ni', 'Te', 'Hf', 'Nb', 'Os', 'Fe', 'Mo', 'Co', 'Rh', 'Si', 'Hg', 'Sc', 'Cr', 'Pb', 'Pd', 'Ag', 'Ge', 'Cd', 'Sb', 'Mg', 'Bi', 'Ir', 'Al', 'Y', 'Zr', 'W', 'Au', 'Pt']
# 40

# %%
data = data[data["EtatEntropie"] == 1]

# %%
data['extracted_elements'] = data['Alloy'].apply(extract_elements)

# Extract all unique elements from the "extracted_elements" column
all_unique_elements_exp = list(set(element for sublist in data['extracted_elements'] for element in sublist))

print(all_unique_elements_exp)
len(all_unique_elements_exp)
# Out:
# ['Re', 'Mn', 'Ti', 'Li', 'Ta', 'V', 'Tb', 'Cu', 'Ru', 'Zn', 'Sn', 'Ni', 'Hf', 'Nb', 'Os', 'Fe', 'Mo', 'Co', 'Rh', 'Si', 'B', 'Sc', 'Cr', 'Tm', 'Pd', 'Ag', 'Ge', 'Dy', 'Mg', 'Pt', 'Ho', 'Ir', 'Lu', 'Al', 'Y', 'Zr', 'C', 'Tc', 'W', 'Au', 'Gd']
# C:\Users\pc\AppData\Local\Temp/ipykernel_1556/4189658457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['extracted_elements'] = data['Alloy'].apply(extract_elements)
# 41

# %%
data
# Out:
#                                  Alloy         A     delta           TM  \
# 0                         Al0.2MoTaTiV  1.990476  0.040740  2489.114286
# 1                         Al0.6MoTaTiV  1.973913  0.047752  2353.834783
# 2                         Al1.5MoNbTiV  1.945455  0.055290  2025.400000
# 3     Hf1.375Nb0.25Ta0.25Ti1.75Zr1.375  2.120000  0.043743  2249.075000
# 4                      Mo0.1NbTiV0.3Zr  2.079412  0.046332  2276.767647
# ...                                ...       ...       ...          ...
# 2323                   FeCoNiCrCuAl2.8  1.331282  0.059952  1469.036667
# 2324                     FeNiCrCoAl2.5  1.339231  0.058390  1510.873077
# 2325                     FeCoNiCrCuAl3  1.333750  0.060208  1455.647500
# 2326               CrMo0.5NbTa0.5TiZr   1.583000  0.094252  2418.400000
# 2327                       CrHfNbTiZr   1.278000  0.512586  2301.000000
#
#       DELTA_TM  Electronegativity  Delta_Electro-        SID       VEC  \
# ...

# %%
filtered_df = data[data['extracted_elements'].apply(lambda elements: all(element in all_unique_elements_calc for element in elements))]

# Extract the alloys from the filtered DataFrame
filtered_alloys = filtered_df['Alloy'].tolist()

print(filtered_alloys)
# Out:
# ['Al0.2MoTaTiV', 'Al0.6MoTaTiV', 'Al1.5MoNbTiV', 'Hf1.375Nb0.25Ta0.25Ti1.75Zr1.375', 'Mo0.1NbTiV0.3Zr', 'Mo0.3NbTiV0.3Zr', 'Mo0.5NbTiV0.3Zr', 'Mo0.7NbTiV0.3Zr', 'Mo1.3NbTiV0.3Zr', 'Mo1.5NbTiV0.3Zr', 'MoNbTaTi0.25W', 'MoNbTaTi0.5W', 'MoNbTaTi0.75W', 'MoNbTiV0.3Zr', 'CoCrCu1FeNiTi0.5', 'VCrFeTa0.1W0.1', 'VCrFeTa0.2W0.2', 'NbTaTi30Zr', 'NbTaTi35Zr', 'NbTaTi40Zr', 'NbTaTi45Zr', 'Ta0.6ZrHfTi', 'Ta0.5ZrHfTi', 'Ta0.4ZrHfTi', 'Ti40Zr25Nb25Ta10', 'Ti45Zr25Nb25Ta5', 'Ti35Zr25Nb25Ta15', 'Ti30Zr25Nb25Ta20', 'Ti25Zr25Nb25Ta25', 'AlCoCrFeNiV0.2', 'AlCoCrFeNiV0.5', 'AlCoCrFeNiV0.8', 'AlCoCrFeNiV1.0', 'Al1.2CoCrFeNiTi0.8', 'Al0.5HfNbTiZr', 'Al0.75HfNbTiZr', 'AlHfNbTiZr', 'Al1.25HfNbTiZr', 'Al1.5HfNbTiZr', 'TiZrHfCr0.2Mo', 'Cr26Mn20Fe20Co20Ni14', 'Ti2ZrHf0.5VNb0.25', 'Ti2ZrHf0.5VNb0.75', 'ZrTiHfCuNiFe', 'AlCrFeCoNi', '(CoCrCuFeNi)96Nb4', 'Al26.6Nb23.8Ti25.1V24.5', 'CoCrFeNiV0.25', 'NbTiV3Zr', 'NbTiV4Zr', 'NbTiV5Zr', 'Al0.3CrFe1.5MnNi', 'Al0.3CrFe1.5MnNi0.5Ti0.2', 'AlHfNbTaTiZr', 'Mo0.5NbHf0.5ZrTiSi0.
# ...

# %%
def get_dict(element):
    import re
    l= {}
    res = re.findall('[A-Z][^A-Z]*', element)
    for element in res:
        if '.' in element :
            l[re.findall("(\d+\.\d+|[A-Za-z]+)", element)[0]] = float(re.findall('(\d+\.\d+|[A-Za-z]+)', element )[1])
        if len(re.findall('(\d+|[A-Za-z]+)', element )) == 2 :
            l[re.findall('(\d+|[A-Za-z]+)', element )[0]] = float(re.findall('(\d+|[A-Za-z]+)', element )[1])
        if len(re.findall('(\d+|[A-Za-z]+)', element )) == 1 :
            l[re.findall('(\d+|[A-Za-z]+)', element )[0]] = 1     
    return l

# %%
get_dict("(CoCrFeMnNi)96Mo4")
# Out:
# {'Co': 1, 'Cr': 1, 'Fe': 1, 'Mn': 1, 'Ni': 96.0, 'Mo': 4.0}
